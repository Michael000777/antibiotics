# %%
import numpy as np
import pandas as pd
import sys,os
import glob
import scipy.optimize as spo
sys.path.append(sys.path[0] + '/../MeasureMSP/')

import matplotlib.pyplot as plt
import matplotlib

from imp import reload
import platereaderclass as prc; reload(prc);
import plates_EstimateMSP as eMSP; reload(eMSP);

# %%
# general plot options

axes_fontsize    = 15  # size of numbers on axes
label_fontsize   = 15  # size of labels for axes
legend_fontsize  = 12
panelID_fontsize = 20  # size of panel indicator (A, B, C, ...)
plot_xfigsize    = 15

# %%
basedir = '../ExperimentalData/'

design_assignment_ChangeEPS = { 'ChangeEPS_WT.xlsx':         [0, 1, 2], 
                                'ChangeEPS_TEM1.xlsx':       [0, 0, 1, 1, 2, 2], 
                                'ChangeEPS_E104KG238S.xlsx': [0, 0, 1, 1, 2, 2],
                                'ChangeEPS_G238S.xlsx':      [0, 0, 1, 1, 2, 2],
                                'ChangeEPS_Triple.xlsx':     [0, 1, 2]}

design_assignment_ChangeRHO = { 'ChangeRHO_G238S.xlsx':      [0, 0, 0, 0, 0, 0, 0, 0],
                                'ChangeRHO_Triple.xlsx':     [0, 0, 1, 1, 1, 1, 0, 0]}

design_assignment           = { 'ChangeEPS_WT.xlsx':         [0, 1, 2], 
                                'ChangeEPS_TEM1.xlsx':       [0, 0, 1, 1, 2, 2], 
                                'ChangeEPS_E104KG238S.xlsx': [0, 0, 1, 1, 2, 2],
                                'ChangeEPS_G238S.xlsx':      [0, 0, 1, 1, 2, 2],
                                'ChangeEPS_Triple.xlsx':     [0, 1, 2],
                                'ChangeRHO_G238S.xlsx':      [0, 0, 0, 0, 0, 0, 0, 0],
                                'ChangeRHO_Triple.xlsx':     [0, 0, 1, 1, 1, 1, 0, 0]}


def make_argparse_options(filename,design_assignment):
    return ['-q','-i',basedir + filename.split('_')[0] + '/' + filename,'-M','NfuncB','BfuncN', '-D'] + [str(i) for i in design_assignment]

def AddDF(df1 = None,df2 = None):
    if df1 is None:    return df2
    elif df2 is None:  return df1
    else:              return pd.concat([df1,df2],ignore_index = True)

def split_allele_name_ChangeEPS(df):
    def split_iptg(allele):
        if allele[-4:].upper() == 'IPTG': return [allele[:-5],allele[-5:]]
        else:                             return [allele,'+IPTG']
    data = [x.strip('andy') for x in df['Title'].values]
    data = np.array([['ChangeEPS',split_iptg(x.split('_')[0])[0],split_iptg(x.split('_')[0])[1],x.split('_')[1]] for x in data])
    df['exp'] = 'ChangeEPS'
    df['Allele'] = data[:,1]
    df['ExprLevel'] = data[:,2]
    df['Repetition'] = data[:,3]
    return df

def split_allele_name_ChangeRHO(df):
    data = np.array([x.split('_') for x in df['Title'].values])
    df['exp'] = 'ChangeRHO'
    df['Allele'] = data[:,0]
    df['ExprLevel'] = data[:,1]
    df['Repetition'] = data[:,2]
    return df

# %%
results_ChangeEPS = None
for datafile in design_assignment_ChangeEPS.keys():
    print(datafile)
    curres = eMSP.EstimateMSP(params = make_argparse_options(datafile,design_assignment_ChangeEPS[datafile]))
    results_ChangeEPS = AddDF(results_ChangeEPS, curres)

results_ChangeRHO = None
for datafile in design_assignment_ChangeRHO.keys():
    print(datafile)
    curres = eMSP.EstimateMSP(params = make_argparse_options(datafile,design_assignment_ChangeRHO[datafile]))
    results_ChangeRHO = AddDF(results_ChangeRHO, curres)
    
results = AddDF(split_allele_name_ChangeEPS(results_ChangeEPS),split_allele_name_ChangeRHO(results_ChangeRHO))

results
# Out:
# ChangeEPS_WT.xlsx
# ChangeEPS_TEM1.xlsx
# ChangeEPS_E104KG238S.xlsx
# ChangeEPS_G238S.xlsx
# ChangeEPS_Triple.xlsx
# ChangeRHO_G238S.xlsx
# ChangeRHO_Triple.xlsx
#                 Title                                           Filename  \
# 0            andyWT_A    ../ExperimentalData/ChangeEPS/ChangeEPS_WT.xlsx
# 1            andyWT_B    ../ExperimentalData/ChangeEPS/ChangeEPS_WT.xlsx
# 2            andyWT_C    ../ExperimentalData/ChangeEPS/ChangeEPS_WT.xlsx
# 3         TEM1-IPTG_A  ../ExperimentalData/ChangeEPS/ChangeEPS_TEM1.xlsx
# 4         TEM1+IPTG_A  ../ExperimentalData/ChangeEPS/ChangeEPS_TEM1.xlsx
# 5         TEM1-IPTG_B  ../ExperimentalData/ChangeEPS/ChangeEPS_TEM1.xlsx
# 6         TEM1+IPTG_B  ../ExperimentalData/ChangeEPS/ChangeEPS_TEM1.xlsx
# 7         TEM1-IPTG_C  ../ExperimentalData/ChangeEPS/ChangeEPS_TEM1.xlsx
# 8         TEM1+IPTG_C  ../ExperimentalData/ChangeEPS/ChangeEPS_TEM1.xlsx
# 9   E104KG238S-IPTG_A  ../ExperimentalData/ChangeEPS/ChangeEPS_E104KG...
# 10  E104KG238S+IPTG_A  ../ExperimentalData/ChangeEPS/ChangeEPS_E104KG...
# 11  E104KG238S-IPTG_B  ../ExperimentalData/ChangeEPS/ChangeEPS_E104KG...
# 12  E104KG238S+IPTG_B  ../ExperimentalData/ChangeEPS/ChangeEPS_E104KG...
# 13  E104KG238S-IPTG_C  ../ExperimentalData/ChangeEPS/ChangeEPS_E104KG...
# 14  E104KG238S+IPTG_C  ../ExperimentalData/ChangeEPS/ChangeEPS_E104KG...
# 15       G238S-IPTG_A  ../ExperimentalData/ChangeEPS/ChangeEPS_G238S....
# 16       G238S+IPTG_A  ../ExperimentalData/ChangeEPS/ChangeEPS_G238S....
# 17       G238S-IPTG_B  ../ExperimentalData/ChangeEPS/ChangeEPS_G238S....
# 18       G238S+IPTG_B  ../ExperimentalData/ChangeEPS/ChangeEPS_G238S....
# 19       G238S-IPTG_C  ../ExperimentalData/ChangeEPS/ChangeEPS_G238S....
# 20       G238S+IPTG_C  ../ExperimentalData/ChangeEPS/ChangeEPS_G238S....
# 21       andyTriple_A  ../ExperimentalData/ChangeEPS/ChangeEPS_Triple...
# 22       andyTriple_B  ../ExperimentalData/ChangeEPS/ChangeEPS_Triple...
# 23       andyTriple_C  ../ExperimentalData/ChangeEPS/ChangeEPS_Triple...
# 24       G238S_None_1  ../ExperimentalData/ChangeRHO/ChangeRHO_G238S....
# 25       G238S_None_2  ../ExperimentalData/ChangeRHO/ChangeRHO_G238S....
# 26       G238S_High_1  ../ExperimentalData/ChangeRHO/ChangeRHO_G238S....
# 27       G238S_High_2  ../ExperimentalData/ChangeRHO/ChangeRHO_G238S....
# 28        G238S_Med_1  ../ExperimentalData/ChangeRHO/ChangeRHO_G238S....
# 29        G238S_Med_2  ../ExperimentalData/ChangeRHO/ChangeRHO_G238S....
# 30        G238S_Low_1  ../ExperimentalData/ChangeRHO/ChangeRHO_G238S....
# 31        G238S_Low_2  ../ExperimentalData/ChangeRHO/ChangeRHO_G238S....
# 32      Triple_None_1  ../ExperimentalData/ChangeRHO/ChangeRHO_Triple...
# 33      Triple_None_2  ../ExperimentalData/ChangeRHO/ChangeRHO_Triple...
# 34      Triple_High_1  ../ExperimentalData/ChangeRHO/ChangeRHO_Triple...
# 35      Triple_High_2  ../ExperimentalData/ChangeRHO/ChangeRHO_Triple...
# 36       Triple_Med_1  ../ExperimentalData/ChangeRHO/ChangeRHO_Triple...
# 37       Triple_Med_2  ../ExperimentalData/ChangeRHO/ChangeRHO_Triple...
# 38       Triple_Low_1  ../ExperimentalData/ChangeRHO/ChangeRHO_Triple...
# 39       Triple_Low_2  ../ExperimentalData/ChangeRHO/ChangeRHO_Triple...
#
#       NB_sMIC  NB_sMIC_stddev        NB_tau  NB_tau_stddev     NB_R2  \
# 0    0.057485        0.107967  1.721031e-07   1.509565e-07  0.565178
# 1    0.043705        0.064954  2.603217e-07   1.708215e-07  0.699012
# 2    0.056324        0.078849  1.883684e-07   1.311983e-07  0.673351
# 3    0.036567        0.023540  3.080493e-07   4.632864e-07  0.306577
# 4    0.034087        0.017761  2.486184e-07   3.243498e-07  0.370096
# 5    0.035006        0.043180  2.844460e-07   1.521564e-07  0.777520
# 6    0.037940        0.043730  2.827461e-07   1.435045e-07  0.795168
# 7    0.026702        0.024979  3.410337e-07   1.948223e-07  0.753949
# 8    0.036541        0.029496  3.137430e-07   1.347172e-07  0.844328
# 9    0.516232        0.369723  1.047349e-06   4.655603e-07  0.835009
# 10   1.199175        0.461930  1.150616e-06   3.228478e-07  0.927017
# 11   0.357538        0.444751  1.211780e-06   7.414019e-07  0.727625
# 12   0.854619        0.431053  1.222721e-06   4.179164e-07  0.895398
# 13   0.374776        0.266914  1.695092e-06   6.191207e-07  0.882299
# 14   0.667702        0.517945  1.570304e-06   7.365290e-07  0.819676
# 15   0.093261        0.038291  3.645633e-07   1.821470e-07  0.800236
# 16   0.135914        0.045871  5.359373e-07   1.160047e-07  0.955245
# 17   0.077260        0.098521  3.835107e-07   1.866836e-07  0.808440
# 18   0.116537        0.166047  3.372236e-07   1.925476e-07  0.754138
# 19   0.056700        0.084228  3.558262e-07   2.146179e-07  0.733248
# 20   0.160294        0.162929  3.187515e-07   1.412640e-07  0.835836
# 21   3.624486        1.846331  4.789953e-06   1.444460e-06  0.916642
# 22   2.821779        2.300427  6.692611e-06   2.869735e-06  0.844693
# 23   2.665014        1.535536  5.102396e-06   1.588506e-06  0.911641
# 24   0.055157        0.021715  3.491481e-07   2.423950e-07  0.674773
# 25   0.053112        0.018086  3.215057e-07   1.407941e-07  0.839085
# 26   0.294647        0.292391  4.384931e-06   1.959287e-06  0.833576
# 27   0.376563        0.275735  4.202841e-06   1.481909e-06  0.889423
# 28   0.246999        0.341547  3.626827e-06   2.037980e-06  0.760022
# 29   0.311037        0.398072  3.458482e-06   2.020523e-06  0.745537
# 30   0.141545        0.095784  2.534787e-06   7.084915e-07  0.927537
# 31   0.173941        0.153438  2.662887e-06   9.440578e-07  0.888346
# 32   0.063714        0.024601  4.236880e-07   2.214879e-07  0.785373
# 33   0.060144        0.060193  8.572559e-07   5.833055e-07  0.683532
# 34  20.059974       40.704877  3.122366e-06   2.854781e-06  0.544678
# 35  16.783396       28.053435  3.489844e-06   2.430172e-06  0.673441
# 36  12.876668       30.441428  5.002971e-06   4.318700e-06  0.573013
# 37   9.034185       16.716939  4.844093e-06   3.305616e-06  0.682281
# 38   1.873690        1.477183  1.867841e-05   1.075629e-05  0.750963
# 39   2.200761        3.337697  7.803940e-06   8.136307e-06  0.479158
#
#       BN_sMIC  BN_sMIC_stddev        BN_tau  BN_tau_stddev     BN_R2  \
# 0    0.103859        0.133159  9.726884e-08   8.531728e-08  0.565178
# 1    0.069469        0.080090  1.819680e-07   1.194063e-07  0.699012
# 2    0.084102        0.090536  1.268380e-07   8.834245e-08  0.673351
# 3    0.044654        0.013181  9.444087e-08   1.420330e-07  0.306577
# 4    0.040912        0.010604  9.201257e-08   1.200404e-07  0.370096
# 5    0.050296        0.051579  2.211624e-07   1.183046e-07  0.777520
# 6    0.052398        0.051129  2.248307e-07   1.141103e-07  0.795168
# 7    0.035003        0.026807  2.571221e-07   1.468861e-07  0.753949
# 8    0.044504        0.031822  2.649021e-07   1.137456e-07  0.844328
# 9    0.621101        0.389914  8.745455e-07   3.887470e-07  0.835009
# 10   1.280525        0.467429  1.066641e-06   2.992854e-07  0.927017
# 11   0.553195        0.535025  8.817212e-07   5.394625e-07  0.727625
# 12   0.945142        0.440939  1.094822e-06   3.742015e-07  0.895398
# 13   0.441350        0.286295  1.495578e-06   5.462496e-07  0.882299
# 14   0.831145        0.554616  1.287139e-06   6.037148e-07  0.819676
# 15   0.102303        0.036362  2.917369e-07   1.457606e-07  0.800236
# 16   0.142428        0.046506  5.119516e-07   1.108130e-07  0.955245
# 17   0.111497        0.121118  3.100454e-07   1.509225e-07  0.808440
# 18   0.183001        0.210840  2.543132e-07   1.452075e-07  0.754138
# 19   0.092613        0.108691  2.609090e-07   1.573682e-07  0.733248
# 20   0.206835        0.184832  2.664239e-07   1.180735e-07  0.835836
# 21   3.994356        1.909037  4.390671e-06   1.324053e-06  0.916642
# 22   3.484099        2.505022  5.653202e-06   2.424045e-06  0.844693
# 23   2.998789        1.611354  4.651551e-06   1.448146e-06  0.911641
# 24   0.061000        0.018747  2.355958e-07   1.635617e-07  0.674773
# 25   0.057120        0.017326  2.697706e-07   1.181382e-07  0.839085
# 26   0.387465        0.334629  3.655173e-06   1.633215e-06  0.833576
# 27   0.444908        0.298145  3.738102e-06   1.318044e-06  0.889423
# 28   0.370908        0.420934  2.756467e-06   1.548909e-06  0.760022
# 29   0.445363        0.465460  2.578425e-06   1.506374e-06  0.745537
# 30   0.158530        0.101744  2.351108e-06   6.571519e-07  0.927537
# 31   0.208758        0.169335  2.365566e-06   8.386501e-07  0.888346
# 32   0.069402        0.022995  3.327533e-07   1.739507e-07  0.785373
# 33   0.082552        0.063106  5.859617e-07   3.987079e-07  0.683532
# 34  35.329400       48.983961  1.700686e-06   1.554938e-06  0.544678
# 35  27.449173       35.146980  2.350204e-06   1.636577e-06  0.673441
# 36  28.716307       45.938976  2.866768e-06   2.474671e-06  0.573013
# 37  16.109630       22.791520  3.305032e-06   2.255359e-06  0.682281
# 38   2.401065        1.528505  1.402680e-05   8.077575e-06  0.750963
# 39   3.834761        3.416496  3.739322e-06   3.898578e-06  0.479158
#
#           exp      Allele ExprLevel Repetition
# 0   ChangeEPS          WT     +IPTG          A
# 1   ChangeEPS          WT     +IPTG          B
# 2   ChangeEPS          WT     +IPTG          C
# 3   ChangeEPS        TEM1     -IPTG          A
# 4   ChangeEPS        TEM1     +IPTG          A
# 5   ChangeEPS        TEM1     -IPTG          B
# 6   ChangeEPS        TEM1     +IPTG          B
# 7   ChangeEPS        TEM1     -IPTG          C
# 8   ChangeEPS        TEM1     +IPTG          C
# 9   ChangeEPS  E104KG238S     -IPTG          A
# 10  ChangeEPS  E104KG238S     +IPTG          A
# 11  ChangeEPS  E104KG238S     -IPTG          B
# 12  ChangeEPS  E104KG238S     +IPTG          B
# 13  ChangeEPS  E104KG238S     -IPTG          C
# 14  ChangeEPS  E104KG238S     +IPTG          C
# 15  ChangeEPS       G238S     -IPTG          A
# 16  ChangeEPS       G238S     +IPTG          A
# 17  ChangeEPS       G238S     -IPTG          B
# 18  ChangeEPS       G238S     +IPTG          B
# 19  ChangeEPS       G238S     -IPTG          C
# 20  ChangeEPS       G238S     +IPTG          C
# 21  ChangeEPS      Triple     +IPTG          A
# 22  ChangeEPS      Triple     +IPTG          B
# 23  ChangeEPS      Triple     +IPTG          C
# 24  ChangeRHO       G238S      None          1
# 25  ChangeRHO       G238S      None          2
# 26  ChangeRHO       G238S      High          1
# 27  ChangeRHO       G238S      High          2
# 28  ChangeRHO       G238S       Med          1
# 29  ChangeRHO       G238S       Med          2
# 30  ChangeRHO       G238S       Low          1
# 31  ChangeRHO       G238S       Low          2
# 32  ChangeRHO      Triple      None          1
# 33  ChangeRHO      Triple      None          2
# 34  ChangeRHO      Triple      High          1
# 35  ChangeRHO      Triple      High          2
# 36  ChangeRHO      Triple       Med          1
# 37  ChangeRHO      Triple       Med          2
# 38  ChangeRHO      Triple       Low          1
# 39  ChangeRHO      Triple       Low          2

# %%
def grid2design(gridcoordinates, plate_size, griddesign = (12.,8.)):
    if isinstance(gridcoordinates[0],(list,tuple,np.ndarray)):
        return np.array([grid2design(gc,plate_size, griddesign) for gc in gridcoordinates])
    else:
        return np.array([ 
                plate_size['Bmin'] * np.power(plate_size['Bmax']/plate_size['Bmin'],gc[0]/(griddesign[0]-1.)),
                plate_size['Nmin'] * np.power(plate_size['Nmax']/plate_size['Nmin'],1. - gc[1]/(griddesign[1]-1.))
            ])


def design2grid(designcoordinates, plate_size, griddesign = (12.,8.)):
    return np.array([[
        (griddesign[0]-1) * (np.log(dc[0]/plate_size['Bmin']))/np.log(plate_size['Bmax']/plate_size['Bmin']),
        (griddesign[1]-1) * (1 - (np.log(dc[1]/plate_size['Nmin']))/np.log(plate_size['Nmax']/plate_size['Nmin']))
    ] for dc in designcoordinates])
    

def adjust_ax(ax, plate_size, fc = '#d3d7cf'):
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    
    xticks = [1e-2,1e-1,1e0,1e1]
    yticks = [1e3,1e5,1e7]
    
    xtickpos = design2grid(np.array([xticks,np.ones_like(xticks)]).T, plate_size = plate_size)[:,0]
    ytickpos = design2grid(np.array([np.ones_like(yticks),yticks]).T, plate_size = plate_size)[:,1]

    ax.set_xticks(xtickpos)
    ax.set_xticklabels([r'$10^{{{:d}}}$'.format(int(np.log10(x))) for x in xticks], fontsize = axes_fontsize)
    ax.set_yticks(ytickpos)
    ax.set_yticklabels([r'$10^{{{:d}}}$'.format(int(np.log10(y))) for y in yticks], fontsize = axes_fontsize)

    ax.set_xlim([-.6,11.6])
    ax.set_ylim([7.6,-.6])
    
    background = matplotlib.patches.Rectangle([ax.get_xlim()[0],ax.get_ylim()[0]],np.diff(ax.get_xlim()),np.diff(ax.get_ylim()), fc = fc, zorder = -1)
    ax.add_patch(background)

    ax.set_xlabel(r'Initial Antibiotic Concentration $B_0$ $[\mu g/ml]$', fontsize = label_fontsize)
    ax.set_ylabel(r'Inoculum size $N_0$', fontsize = label_fontsize)
    
    
def patch_color(value, color1 = [ 65,101,164], color2 = [255,255,255], hexoutput = True):
    value = np.max([0,np.min([1,value])])
    if hexoutput:
        return '#{:02X}{:02X}{:02X}'.format(int(color1[0] * value + color2[0] * (1-value)),int(color1[1] * value + color2[1] * (1-value)),int(color1[2] * value + color2[2] * (1-value)))
    else:
        return [int(color1[0] * value + color2[0] * (1-value)),int(color1[1] * value + color2[1] * (1-value)),int(color1[2] * value + color2[2] * (1-value))]

def plot_well(ax, pos, value, thres, plate_pos, plate_data_shape, radius = 0.4):
    border_color = '#2e3436'
    if value <= thres:
        border_color = '#a40000'
    circle = matplotlib.patches.Circle(pos,radius,facecolor = patch_color(value), edgecolor = border_color, linewidth = 3)
    ax.add_patch(circle)

    
def rescale(platedata, threshold):
    return (platedata - np.min(platedata))/(np.max(platedata) - np.min(platedata)),(threshold - np.min(platedata))/(np.max(platedata)-np.min(platedata))


def BfuncN(N, tau, smic): return smic*np.exp((N-1)/tau)
def NfuncB(B, tau, smic): return 1 + tau * np.log(B/smic)

# %%
all_raw_data_files = list(glob.glob(basedir + '/*/*.xlsx'))
all_design_assignments = [np.array(design_assignment[os.path.split(filename)[1]]) for filename in all_raw_data_files]
for i in range(1,len(all_design_assignments)):
    all_design_assignments[i] += np.max(all_design_assignments[i-1]) + 1
all_design_assignments = np.concatenate(all_design_assignments)


all_platedata = prc.PlateReaderData(infiles = all_raw_data_files, DesignAssignment = all_design_assignments)
threshold     = all_platedata.EstimateGrowthThreshold()

# %%
def PlotPlates(ax, platedata, design, threshold, msp_parameters):
    platesize = {'Bmin':design[0][0,0],
                 'Bmax':design[0][-1,-1],
                 'Nmin':np.min(design[1]),
                 'Nmax':np.max(design[1])}
    
    for x in range(platedata.shape[0]):
        for y in range(platedata.shape[1]):
            plot_well(ax, [x,y], platedata[x,y], threshold, platesize, platedata.shape)

    nlist = np.exp(np.linspace(np.log(platesize['Nmin']/10),np.log(platesize['Nmax']*10),50))
    for msp_parameter in msp_parameters:
        blist    = BfuncN(nlist, 1./msp_parameter['NB_tau'], msp_parameter['NB_sMIC'])
        mspcurve = design2grid(np.array([blist,nlist]).T, platesize)
        ax.plot(mspcurve[:,0],mspcurve[:,1], lw = msp_parameter['lw'], c = msp_parameter['color'], zorder = 100)
    
    adjust_ax(ax, platesize)

# %%
for filename in all_raw_data_files:
    print(filename)
    xlsx = os.path.split(filename)[1]
    plates = prc.PlateReaderData(infiles = [filename], DesignAssignment = design_assignment[xlsx])
    for i,(fn,title,platedata,da) in enumerate(plates):
        mspfitresults = results[results['Title']==title.replace(' ','_')]
        mspparameters = [{'NB_tau':mspfitresults['NB_tau'].values[0] + a * mspfitresults['NB_tau_stddev'].values[0],
                          'NB_sMIC':mspfitresults['NB_sMIC'].values[0] + a * mspfitresults['NB_sMIC_stddev'].values[0],
                         'lw':5-2*a*a,
                         'color':'red' if a==0 else 'orange'} for a in [-1,0,1]]
        fig,ax = plt.subplots(1,1,figsize = (plot_xfigsize/2,5.5))
        platedata, thr = rescale(platedata.T, threshold)
        PlotPlates(ax, platedata, plates.get_design(da), thr, mspparameters)
        ax.set_title('{} {} {}'.format(xlsx.split('_')[0],title,i+1))
        fig.savefig('plates_{}_{}.png'.format(xlsx[:-5],i+1))
    
    # delete this break statement to run over all files
    # now it breaks after analyzing first file
    break
# Out:
# ../ExperimentalData/ChangeEPS/ChangeEPS_WT.xlsx
# <ipython-input-8-5f4feccb7d40>:13: RuntimeWarning: invalid value encountered in log
#   (griddesign[0]-1) * (np.log(dc[0]/plate_size['Bmin']))/np.log(plate_size['Bmax']/plate_size['Bmin']),
# /usr/lib64/python3.10/site-packages/numpy/core/fromnumeric.py:43: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = getattr(asarray(obj), method)(*args, **kwds)
